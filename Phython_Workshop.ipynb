# %% [markdown]
# <a href="https://colab.research.google.com/github/murugaveluviji/Day-1/blob/main/Phython_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keyword
print("standrd keyword=",len(keyword.kwlist))
print("soft keyword=",keyword.softkwlist)
print("All keyword=",keyword.kwlist)
# Out:
# standrd keyword= 35
# soft keyword= ['_', 'case', 'match', 'type']
# All keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x=5
y="python"
z=3.0
print(x)
print(y)
print(z)
print(type(x))
print(type(y))
print (type(z))
# Out:
# 5
# python
# 3.0
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
y1=2
print(y1)
print(type(y1))

y2=float(y1)
print(y2)
print(type(y2))

y3=(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'int'>

# %%
y1=(2)
y2=float(2)
y3=str(2)

print(y1)
print(y2)
print(y3)

print(type(y1))
print(type(y2))
print(type(y3))
# Out:
# 2
# 2.0
# 2
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
c=50
d=float(c)

# %%
a=2
A="Ramana"

# %%
print("Hello, SRU")
print("Hello, SRU")
print("Hello, SRU")
print("Hello, SRU")
print("Hello, SRU")
# Out:
# Hello, SRU
# Hello, SRU
# Hello, SRU
# Hello, SRU
# Hello, SRU

# %% [markdown]
# **WHILE LOOP**

# %%
i=1 #Initialize Variable
while(i<=5):  #while(condition):
   print("Hello, SRU")
   i=i+1   #increment variable value
# Out:
# Hello, SRU
# Hello, SRU
# Hello, SRU
# Hello, SRU
# Hello, SRU

# %% [markdown]
# **Print number table**

# %%
num=input("which number table you want to print")
num=int(num)
i=1
while(i<=10):
  print(f"{num} * {i} = {num*i}")
  i=i+1
# Out:
# which number table you want to print50
# 50 * 1 = 50
# 50 * 2 = 100
# 50 * 3 = 150
# 50 * 4 = 200
# 50 * 5 = 250
# 50 * 6 = 300
# 50 * 7 = 350
# 50 * 8 = 400
# 50 * 9 = 450
# 50 * 10 = 500

# %% [markdown]
# **Break Statement**

# %%
num=input("which number table you want to print")
num=int(num)
i=1
while(i<=10):
  print(f"{num} * {i} = {num*i}")
  if(1==5):
    break
  i=i+1
# Out:
# which number table you want to print50
# 50 * 1 = 50
# 50 * 2 = 100
# 50 * 3 = 150
# 50 * 4 = 200
# 50 * 5 = 250
# 50 * 6 = 300
# 50 * 7 = 350
# 50 * 8 = 400
# 50 * 9 = 450
# 50 * 10 = 500

# %%
List_of_Books=["python", "java", "C", "C++"]
book=input("enter book you want in library")
book_no=0 #start from index 0
while(book_no < len(List_of_Books)):
  if(book==List_of_Books[book_no]):
    print("yes, book available")
    break
  book_no=book_no+1
# Out:
# enter book you want in libraryJava

# %%
List_of_Books=["python", "java", "C", "C++"]
book=input("enter book you want in library")
book_no=0 #start from index 0
while(book_no < len(List_of_Books)):
  if(book==List_of_Books[book_no]):
    print("yes, book available")
    break
  book_no=book_no+1
else:
  print("book not available")
# Out:
# enter book you want in libraryC++
# yes, book available

# %% [markdown]
# **Neted While Loops**

# %%
i=2
while(i<=5):
  print(f"{i} table")
  j=1
  while(j<=10):
   print(f"{i} * {j} = {i*j}")
   j=j+1
  i=i+1
# Out:
# 2 table
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
# 3 table
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30
# 4 table
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40
# 5 table
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# **For loop**

# %%
print(list(range(5)))
# Out:
# [0, 1, 2, 3, 4]

# %%
print(list(range(2,10)))
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]

# %%
print(list(range(2,10,2)))
# Out:
# [2, 4, 6, 8]

# %%
print(list(range(10,2,-2)))
# Out:
# [10, 8, 6, 4]

# %%
for i in range(5):
  print("welcome SRU")
# Out:
# welcome SRU
# welcome SRU
# welcome SRU
# welcome SRU
# welcome SRU

# %%
for i in range(5):
  print("A"*(i+1))
# Out:
# A
# AA
# AAA
# AAAA
# AAAAA

# %% [markdown]
# **For loop with Break Statement**

# %%
List_of_Books=["python", "java", "C", "C++"]
book=input("enter book you want in library")
no_of_books=len(List_of_Books)
for book_no in range(no_of_books):
  if(book==List_of_Books[book_no]):
    print("yes, book available")
    break
# Out:
# enter book you want in libraryC
# yes, book available

# %%
List_of_Books=["python", "java", "C", "C++"]
book=input("enter book you want in library")
no_of_books=len(List_of_Books)
for book_no in range(no_of_books):
  if(book==List_of_Books[book_no]):
    print("yes, book available")
    break
    print("book no=", boo_no)
# Out:
# enter book you want in libraryC
# yes, book available

# %% [markdown]
# For loop with Continue Statement

# %%
for i in range(5):
  if(i==2):
    continue
  print("i=", i)
# Out:
# i= 0
# i= 1
# i= 3
# i= 4

# %% [markdown]
# **Nested For Loops**

# %%
for i in range(5):
  for j in range(i+1):
    print("*",end=" ")
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
for i in range(3):
  for j in range(3):
    if(i!=j):
      print(i,j)
      break
    print("=====")
# Out:
# =====
# 0 1
# 1 0
# 2 0

# %% [markdown]
# **Membership operators for strings**

# %%
subject='python'
print('python' in subject)
print('progamming' in subject)
print('java' not in subject)
# Out:
# True
# False
# True

# %% [markdown]
# **strings are immutable**

# %%
s='Mr.Velu'
print(s[0])
s[0]='D'
# Out:
# M
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2135/3822068822.py in <cell line: 0>()
#       1 s='Mr.Velu'
#       2 print(s[0])
# ----> 3 s[0]='D'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# **String Formating**

# %%
name="Velu"
age=40
print("My name is %s and age is %d")
# Out:
# My name is %s and age is %d

# %%
college="SRU"
print("my college:",college.center(6,'*'))
print("my college:",college.center(8,'*'))
print("my college:",college.center(9,'*'))
print("my college:",college.center(9))
# Out:
# my college: *SRU**
# my college: **SRU***
# my college: ***SRU***
# my college:    SRU
